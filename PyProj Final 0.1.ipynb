# %%
from tkinter import *
from random import *
import os

  
creds = 'tempfile.txt'    
    
    

def Signup():  
    global pwordE 
    global nameE
    global roots
 
    roots = Tk() 
    roots.title('Signup')
    roots.geometry('50000x40000')
    F=Frame(roots,height=50000,width=40000,bg='sky blue')
    
    intruction = Label(F, text='EXAMINATION  REGISTRATION\n',width=35,font=("bold",40),fg="brown",bg='sky blue') 
    intruction.place(x=150,y=50) 
    instruction1 = Label(F, text=' INSTRUCTIONS:\n 1. Please enter your Credentials.\n 2. Special cases are acceptable.\n 3. Use a strong password.',width=25,font=("bold",25),bg='yellow',fg='blue',justify='left')
    instruction1.place(x=10,y=200)
    nameL = Label(F, text='►  New Username  : ',font=("bold",18),bg='sky blue') 
    pwordL = Label(F, text='►  New Password  : ',font=("bold",18),bg='sky blue')
    nameL.place(x=400,y=425) 
    pwordL.place(x=400,y=505) 
 
    nameE = Entry(F) 
    pwordE = Entry(F, show='*') 
    nameE.place(x=650,y=435,width=160) 
    pwordE.place(x=650,y=515,width=160) 
 
    signupButton = Button(F, text='Signup', command=FSSignup,width=35,height=2,bg="brown",fg="white",font=("bold",16)) 
    signupButton.place(x=900,y=650)
    F.pack()
    roots.mainloop() 
def FSSignup():
    with open(creds, 'w') as f: 
        f.write(nameE.get()) 
        f.write('\n') 
        f.write(pwordE.get()) 
        f.close() 
    
    roots.destroy() 
    Login() 
def Login():
    global nameEL
    global pwordEL 
    global rootA
 
    rootA = Tk() 
    rootA.title('Login')
    rootA.geometry('5000x4000')
    FA=Frame(rootA,height=5000,width=4000,bg='sky blue')
    rootA.geometry('5000x4000')
    intruction = Label(FA, text='EXAMINATION  LOGIN\n',width=35,font=("bold",40),fg="brown",bg='sky blue') 
    intruction.place(x=100,y=50) 
 
    nameL = Label(FA, text='► Username  : ',font=("bold",18),bg='sky blue')
    pwordL = Label(FA, text='► Password  : ',font=("bold",18),bg='sky blue')
    nameL.place(x=350,y=305)
    pwordL.place(x=350,y=405)
 
    nameEL = Entry(FA)
    pwordEL = Entry(FA, show='*')
    nameEL.place(x=550,y=315,width=160)
    pwordEL.place(x=550,y=415,width=160)
 
    loginB = Button(FA, text='Login', command=CheckLogin,width=30,height=2,bg="brown",fg="white",font=("bold",16))
    loginB.place(x=900,y=500)
 
    rmuser = Button(FA, text='Delete User', fg='red', command=DelUser,width=30,height=2,font=("bold",16))
    rmuser.place(x=900,y=600)
    FA.pack()
    rootA.mainloop()
def CheckLogin():
    with open(creds) as f:
        data = f.readlines()
        uname = data[0].rstrip() # Data[0], 0 is the first line, 1 is the second and so on.
        #The method rstrip() returns a copy of the string in which all chars have been stripped from the end of the string (default whitespace characters).
        pword = data[1].rstrip() # Using .rstrip() will remove the \n (new line) word from before when we input it
 
    if nameEL.get() == uname and pwordEL.get() == pword:
        def Welcome():
            rootA.destroy()
            global score
            
            root3= Tk()
            var1=IntVar()
            var2=IntVar()
            var3=IntVar()
            var4=IntVar()
            var5=IntVar()
            var6=IntVar()
            var7=IntVar()
            var8=IntVar()
            var9=IntVar()
            var10=IntVar()
            var11=IntVar()
            var12=IntVar()
            var13=IntVar()
            var14=IntVar()
            var15=IntVar()
            var16=IntVar()
            var17=IntVar()
            var18=IntVar()
            var19=IntVar()
            var20=IntVar()
            var21=IntVar()
            var22=IntVar()
            var23=IntVar()
            var24=IntVar()
            var25=IntVar()
    
            f1=Frame(root3,height=1000,width=2000,bg='sky blue')
            out=Label(f1,text='► WELCOME TO THE MULTIPLE CHOICE TEST ◄\n',width=40,font=("bold",35),fg="brown",bg='sky blue')
            out.place(x=130,y=20)
            out2=Label(f1,text='♦ INSTRUCTIONS ♦\n\n1. Hey! Let us play a Quiz!\n2. You will be asked 20 questions and four choices will be given for each question.\n3. You have to select which choice is the correct answer.\n4. You have to complete the quiz in 20 mins.',width=65,font=("bold",25),fg='blue',bg='yellow',justify='left')
            out2.place(x=10,y=200)
    
            def sel():
                f1.destroy()       
                f2.pack() 
    
            def sel1():
                f2.destroy()
                f3.pack()    
            f2 = Frame(root3,height=1000,width=2000,bg='sky blue')
            t1=Label(f2,text='Q1. Which country will host the 2020 Olympic Games? ',font=('bold',20),bg='sky blue')
            t1.place(x=10,y=10)
            r1 = Radiobutton(f2, text="Germany", variable=var1, value=1,font=('bold',14),bg='sky blue',fg='brown')
            r1.place(x=10,y=50)
            r2 = Radiobutton(f2, text="Japan", variable=var1, value=2,font=('bold',14),bg='sky blue',fg='brown')
            r2.place(x=190,y=50)
            r3 = Radiobutton(f2, text="Russia    ", variable=var1, value=3,font=('bold',14),bg='sky blue',fg='brown')
            r3.place(x=10,y=80)
            r4 = Radiobutton(f2, text="France", variable=var1, value=4,font=('bold',14),bg='sky blue',fg='brown')
            r4.place(x=190,y=80)
    
            t1=Label(f2,text='Q2. Who is known as the father of Indian Space Programe? ',font=('bold',20),bg='sky blue')
            t1.place(x=10,y=130)
            r5 = Radiobutton(f2, text="Homi Bhabha", variable=var2, value=1,font=('bold',14),bg='sky blue',fg='brown')
            r5.place(x=10,y=180)
            r6 = Radiobutton(f2, text="K.Shivan", variable=var2, value=2,font=('bold',14),bg='sky blue',fg='brown')
            r6.place(x=190,y=180)
            r7 = Radiobutton(f2, text="A.S.Kiran Kumar", variable=var2, value=3,font=('bold',14),bg='sky blue',fg='brown')
            r7.place(x=10,y=210)
            r8= Radiobutton(f2, text="Vikram Sarabhai", variable=var2, value=4,font=('bold',14),bg='sky blue',fg='brown')
            r8.place(x=190,y=210)
    
            t1=Label(f2,text='Q3. Group of 4 bits Forms a _____',font=('bold',20),bg='sky blue')
            t1.place(x=10,y=260)
            r9 = Radiobutton(f2, text="Octet", variable=var3, value=1,font=('bold',14),bg='sky blue',fg='brown')
            r9.place(x=10,y=310)
            r10 = Radiobutton(f2, text="Nibble", variable=var3, value=2,font=('bold',14),bg='sky blue',fg='brown')
            r10.place(x=190,y=310)
            r11 = Radiobutton(f2, text="Byte", variable=var3, value=3,font=('bold',14),bg='sky blue',fg='brown')
            r11.place(x=10,y=340)
            r12= Radiobutton(f2, text="KiloByte", variable=var3, value=4,font=('bold',14),bg='sky blue',fg='brown')
            r12.place(x=190,y=340)
    
            t1=Label(f2,text='Q4. Value of Total goods and services in a country is its _______ ',font=('bold',20),bg='sky blue')
            t1.place(x=10,y=390)
            r13 = Radiobutton(f2, text="Gross National Product", variable=var4, value=1,font=('bold',14),bg='sky blue',fg='brown')
            r13.place(x=10,y=440)
            r14 = Radiobutton(f2, text="Net Domestic Product", variable=var4, value=2,font=('bold',14),bg='sky blue',fg='brown')
            r14.place(x=250,y=440)
            r15 = Radiobutton(f2, text="Gross Domestic Product", variable=var4, value=3,font=('bold',14),bg='sky blue',fg='brown')
            r15.place(x=10,y=470)
            r16= Radiobutton(f2, text="Net National Product", variable=var4, value=4,font=('bold',14),bg='sky blue',fg='brown')
            r16.place(x=250,y=470)
    
            t1=Label(f2,text='Q5. Which Actor won the best actor award in the 1st FilmFare Awards? ',font=('bold',20),bg='sky blue')
            t1.place(x=10,y=520)
            r17 = Radiobutton(f2, text="Dilip Kumar", variable=var5, value=1,font=('bold',14),bg='sky blue',fg='brown')
            r17.place(x=10,y=570)
            r18 = Radiobutton(f2, text="Rajesh Khanna", variable=var5, value=2,font=('bold',14),bg='sky blue',fg='brown')
            r18.place(x=190,y=570)
            r19 = Radiobutton(f2, text="Dev Anand", variable=var5, value=3,font=('bold',14),bg='sky blue',fg='brown')
            r19.place(x=10,y=600)
            r20= Radiobutton(f2, text="Shammi Kapoor", variable=var5, value=4,font=('bold',14),bg='sky blue',fg='brown')
            r20.place(x=190,y=600)
            B1=Button(f2,height=2,width=20,text='Next',command=sel1,font=('bold',15),bg='brown',fg='white')
            B1.place(x=1000,y=650)
    
            def sel2():  
                f3.destroy()
                f4.pack()
            f3= Frame(root3,height=1000,width=2000,bg='sky blue')
            t2=Label(f3,text='Q6. The First Programming Language was _____ ',font=('bold',20),bg='sky blue')
            t2.place(x=10,y=30)
            r21 = Radiobutton(f3, text="COBOL", variable=var6, value=1,font=('bold',14),bg='sky blue',fg='brown')
            r21.place(x=10,y=80)
            r22 = Radiobutton(f3, text="FORTRAN", variable=var6, value=2,font=('bold',14),bg='sky blue',fg='brown')
            r22.place(x=190,y=80)
            r23 = Radiobutton(f3, text="PASCAL", variable=var6, value=3,font=('bold',14),bg='sky blue',fg='brown')
            r23.place(x=10,y=120)
            r24= Radiobutton(f3, text="Binary", variable=var6, value=4,font=('bold',14),bg='sky blue',fg='brown')
            r24.place(x=190,y=120)
    
            t2=Label(f3,text='Q7. The RedCliff Line is the International border Between ______ ',font=('bold',20),bg='sky blue')
            t2.place(x=10,y=170)
            r25 = Radiobutton(f3, text="India and China", variable=var7, value=1,font=('bold',14),bg='sky blue',fg='brown')
            r25.place(x=10,y=220)
            r26 = Radiobutton(f3, text="Russia and China", variable=var7, value=2,font=('bold',14),bg='sky blue',fg='brown')
            r26.place(x=220,y=220)
            r27 = Radiobutton(f3, text="India and Bangladesh", variable=var7, value=3,font=('bold',14),bg='sky blue',fg='brown')
            r27.place(x=10,y=260)
            r28= Radiobutton(f3, text="Myanmar and India", variable=var7, value=4,font=('bold',14),bg='sky blue',fg='brown')
            r28.place(x=220,y=260)
    
            t2=Label(f3,text='Q8. Which is the worlds largest Gold producing Country? ',font=('bold',20),bg='sky blue')
            t2.place(x=10,y=310)
            r29 = Radiobutton(f3, text="China", variable=var8, value=1,font=('bold',14),bg='sky blue',fg='brown')
            r29.place(x=10,y=360)
            r30 = Radiobutton(f3, text="USA", variable=var8, value=2,font=('bold',14),bg='sky blue',fg='brown')
            r30.place(x=190,y=360)
            r31 = Radiobutton(f3, text="Russia", variable=var8, value=3,font=('bold',14),bg='sky blue',fg='brown')
            r31.place(x=10,y=400)
            r32= Radiobutton(f3, text="Australia", variable=var8, value=4,font=('bold',14),bg='sky blue',fg='brown')
            r32.place(x=190,y=400)
    
            t2=Label(f3,text='Q9. Where is the headquarter of United Nations Organisation is located(UNO)? ',font=('bold',20),bg='sky blue')
            t2.place(x=10,y=450)
            r33 = Radiobutton(f3, text="California", variable=var9, value=1,font=('bold',14),bg='sky blue',fg='brown')
            r33.place(x=10,y=500)
            r34 = Radiobutton(f3, text="Amsterdam", variable=var9, value=2,font=('bold',14),bg='sky blue',fg='brown')
            r34.place(x=190,y=500)
            r35 = Radiobutton(f3, text="Washington", variable=var9, value=3,font=('bold',14),bg='sky blue',fg='brown')
            r35.place(x=10,y=540)
            r36= Radiobutton(f3, text="NewYork", variable=var9, value=4,font=('bold',14),bg='sky blue',fg='brown')
            r36.place(x=190,y=540)
    
            t2=Label(f3,text='Q10. Who is the 1st Emperor of Delhi Sultanate? ',font=('bold',20),bg='sky blue')
            t2.place(x=10,y=590)
            r37 = Radiobutton(f3, text="Mohammad Gauri", variable=var10, value=1,font=('bold',14),bg='sky blue',fg='brown')
            r37.place(x=10,y=640)
            r38 = Radiobutton(f3, text="Iltutmish", variable=var10, value=2,font=('bold',14),bg='sky blue',fg='brown')
            r38.place(x=190,y=640)
            r39 = Radiobutton(f3, text="Qutubuddin Aibak", variable=var10, value=3,font=('bold',14),bg='sky blue',fg='brown')
            r39.place(x=10,y=680)
            r40= Radiobutton(f3, text="Gayasuddin Balban", variable=var10, value=4,font=('bold',14),bg='sky blue',fg='brown')
            r40.place(x=190,y=680)
            B1=Button(f3,height=2,width=20,text='Next',command=sel2,font=('bold',15),bg='brown',fg='white')
            B1.place(x=1000,y=650)
            
            def sel3(): 
                f4.destroy()
                f5.pack()
            f4= Frame(root3,height=1000,width=2000,bg='sky blue')
            t3=Label(f4,text="Q11. India's 1st Nuclear Test 'Smiling Buddha' Conducted in which state? ",font=('bold',20),bg='sky blue')
            t3.place(x=10,y=30)
            r45 = Radiobutton(f4, text="Jammu & Kashmir", variable=var12, value=1,font=('bold',14),bg='sky blue',fg='brown')
            r45.place(x=10,y=80)
            r46 = Radiobutton(f4, text="Rajasthan", variable=var12, value=2,font=('bold',14),bg='sky blue',fg='brown')
            r46.place(x=190,y=80)
            r47 = Radiobutton(f4, text="Uttarakhand", variable=var12, value=3,font=('bold',14),bg='sky blue',fg='brown')
            r47.place(x=10,y=120)
            r48= Radiobutton(f4, text="Uttar Pradesh", variable=var12, value=4,font=('bold',14),bg='sky blue',fg='brown')
            r48.place(x=190,y=120)
    
            t3=Label(f4,text='Q12. When was Indian Navy Act Passed? ',font=('bold',20),bg='sky blue')
            t3.place(x=10,y=170)
            r49 = Radiobutton(f4, text="1927", variable=var13, value=1,font=('bold',14),bg='sky blue',fg='brown')
            r49.place(x=10,y=220)
            r50 = Radiobutton(f4, text="1911", variable=var13, value=2,font=('bold',14),bg='sky blue',fg='brown')
            r50.place(x=190,y=220)
            r51 = Radiobutton(f4, text="1932", variable=var13, value=3,font=('bold',14),bg='sky blue',fg='brown')
            r51.place(x=10,y=260)
            r52= Radiobutton(f4, text="1930", variable=var13, value=4,font=('bold',14),bg='sky blue',fg='brown')
            r52.place(x=190,y=260)
    
            t3=Label(f4,text='Q13. Origin of Kathak Kali Dance is from which state of India?  ',font=('bold',20),bg='sky blue')
            t3.place(x=10,y=310)
            r53 = Radiobutton(f4, text="Karnataka", variable=var14, value=1,font=('bold',14),bg='sky blue',fg='brown')
            r53.place(x=10,y=360)
            r54 = Radiobutton(f4, text="Manipur", variable=var14, value=2,font=('bold',14),bg='sky blue',fg='brown')
            r54.place(x=190,y=360)
            r55 = Radiobutton(f4, text="Kerala", variable=var14, value=3,font=('bold',14),bg='sky blue',fg='brown')
            r55.place(x=10,y=400)
            r56= Radiobutton(f4, text="Assam", variable=var14, value=4,font=('bold',14),bg='sky blue',fg='brown')
            r56.place(x=190,y=400)
    
            t3=Label(f4,text='Q14. Which among the following is present inside the nucleus of an atom?',font=('bold',20),bg='sky blue')
            t3.place(x=10,y=450)
            r57 = Radiobutton(f4, text="Protons", variable=var15, value=1,font=('bold',14),bg='sky blue',fg='brown')
            r57.place(x=10,y=500)
            r58 = Radiobutton(f4, text="Neutrons and Electrons", variable=var15, value=2,font=('bold',14),bg='sky blue',fg='brown')
            r58.place(x=190,y=500)
            r59 = Radiobutton(f4, text="Electrons", variable=var15, value=3,font=('bold',14),bg='sky blue',fg='brown')
            r59.place(x=10,y=540)
            r60= Radiobutton(f4, text="Protons and Neutrons", variable=var15, value=4,font=('bold',14),bg='sky blue',fg='brown')
            r60.place(x=190,y=540)
    
            t3=Label(f4,text='Q15. Which Country Has the largest Coastline? ',font=('bold',20),bg='sky blue')
            t3.place(x=10,y=590)
            r61 = Radiobutton(f4, text="Indonesia", variable=var16, value=1,font=('bold',14),bg='sky blue',fg='brown')
            r61.place(x=10,y=640)
            r62 = Radiobutton(f4, text="Russia", variable=var16, value=2,font=('bold',14),bg='sky blue',fg='brown')
            r62.place(x=190,y=640)
            r63 = Radiobutton(f4, text="Greenland", variable=var16, value=3,font=('bold',14),bg='sky blue',fg='brown')
            r63.place(x=10,y=680)
            r64= Radiobutton(f4, text="Canada", variable=var16, value=4,font=('bold',14),bg='sky blue',fg='brown')
            r64.place(x=190,y=680)
            B2=Button(f4,height=2,width=20,text='Next',command=sel3,font=('bold',15),bg='brown',fg='white')
            B2.place(x=1000,y=650)
            
            def sel4():
                f5.destroy()
                f6.pack()
            f5= Frame(root3,height=1000,width=2000,bg='sky blue')
            t4=Label(f5,text='Q16. Who received the golden ball award for best player at the FIFA World Cup 2018? ',font=('bold',20),bg='sky blue')
            t4.place(x=10,y=30)
            r69 = Radiobutton(f5, text="Kylian Mbappe", variable=var18, value=1,font=('bold',14),bg='sky blue',fg='brown')
            r69.place(x=10,y=80)
            r70 = Radiobutton(f5, text="Luka Modric", variable=var18, value=2,font=('bold',14),bg='sky blue',fg='brown')
            r70.place(x=190,y=80)
            r71 = Radiobutton(f5, text="Harry Kane", variable=var18, value=3,font=('bold',14),bg='sky blue',fg='brown')
            r71.place(x=10,y=120)
            r72= Radiobutton(f5, text="Thibaut Courtois", variable=var18, value=4,font=('bold',14),bg='sky blue',fg='brown')
            r72.place(x=190,y=120)
    
            t4=Label(f5,text='Q17. Which is the longest National Highway in India? ',font=('bold',20),bg='sky blue')
            t4.place(x=10,y=170)
            r73 = Radiobutton(f5, text="NH7", variable=var19, value=1,font=('bold',14),bg='sky blue',fg='brown')
            r73.place(x=10,y=220)
            r74 = Radiobutton(f5, text="NH9", variable=var19, value=2,font=('bold',14),bg='sky blue',fg='brown')
            r74.place(x=190,y=220)
            r75 = Radiobutton(f5, text="NH44", variable=var19, value=3,font=('bold',14),bg='sky blue',fg='brown')
            r75.place(x=10,y=260)
            r76= Radiobutton(f5, text="NH10", variable=var19, value=4,font=('bold',14),bg='sky blue',fg='brown')
            r76.place(x=190,y=260)
    
            t4=Label(f5,text='Q18. The Scientists from which IIT institute has created mini-organs that mimic hair growth? ',font=('bold',20),bg='sky blue')
            t4.place(x=10,y=310)
            r77 = Radiobutton(f5, text="IIT Delhi", variable=var20, value=1,font=('bold',14),bg='sky blue',fg='brown')
            r77.place(x=10,y=360)
            r78 = Radiobutton(f5, text="IIT Kolkata", variable=var20, value=2,font=('bold',14),bg='sky blue',fg='brown')
            r78.place(x=190,y=360)
            r79 = Radiobutton(f5, text="IIT Bombay", variable=var20, value=3,font=('bold',14),bg='sky blue',fg='brown')
            r79.place(x=10,y=400)
            r80= Radiobutton(f5, text="IIT Indore", variable=var20, value=4,font=('bold',14),bg='sky blue',fg='brown')
            r80.place(x=190,y=400)
    
            t4=Label(f5,text='Q19. The supreme command of the Indian Defence forces is vested with the? ',font=('bold',20),bg='sky blue')
            t4.place(x=10,y=450)
            r81 = Radiobutton(f5, text="Field Marshal", variable=var21, value=1,font=('bold',14),bg='sky blue',fg='brown')
            r81.place(x=10,y=500)
            r82 = Radiobutton(f5, text="Prime Minister of India", variable=var21, value=2,font=('bold',14),bg='sky blue',fg='brown')
            r82.place(x=190,y=500)
            r83 = Radiobutton(f5, text="Defence Minister", variable=var21, value=3,font=('bold',14),bg='sky blue',fg='brown')
            r83.place(x=10,y=540)
            r84= Radiobutton(f5, text="President of India", variable=var21, value=4,font=('bold',14),bg='sky blue',fg='brown')
            r84.place(x=190,y=540)
    
            t4=Label(f5,text="Q20. Which of the following missiles of india is a 'SuperSonic cruise missile'",font=('bold',20),bg='sky blue')
            t4.place(x=10,y=590)
            r85 = Radiobutton(f5, text="Agni-V", variable=var22, value=1,font=('bold',14),bg='sky blue',fg='brown')
            r85.place(x=10,y=640)
            r86 = Radiobutton(f5, text="BrahMos", variable=var22, value=2,font=('bold',14),bg='sky blue',fg='brown')
            r86.place(x=190,y=640)
            r87 = Radiobutton(f5, text="Prithvi-III", variable=var22, value=3,font=('bold',14),bg='sky blue',fg='brown')
            r87.place(x=10,y=680)
            r88= Radiobutton(f5, text="Aakash", variable=var22, value=4,font=('bold',14),bg='sky blue',fg='brown')
            r88.place(x=190,y=680)
            B3=Button(f5,height=2,width=20,text='Next',command=sel4,font=('bold',15),bg='brown',fg='white')
            B3.place(x=1000,y=650)
    
            def sel5():
                score=0
                f6.destroy()
                radioSel1=var1.get()
                radioSel2=var2.get()
                radioSel3=var3.get()
                radioSel4=var4.get()
                radioSel5=var5.get()
                radioSel6=var6.get()
                radioSel7=var7.get()
                radioSel8=var8.get()
                radioSel9=var9.get()
                radioSel10=var10.get()
                radioSel11=var11.get()
                radioSel12=var12.get()
                radioSel13=var13.get()
                radioSel14=var14.get()
                radioSel15=var15.get()
                radioSel16=var16.get()
                radioSel17=var17.get()
                radioSel18=var18.get()
                radioSel19=var19.get()
                radioSel20=var20.get()
                radioSel21=var21.get()
                radioSel22=var22.get()
                radioSel23=var23.get()
                radioSel24=var24.get()
                radioSel25=var25.get()
                if B4:
                    if radioSel1==2:
                        score=score+1
                        print('Ans1-Correct!')
                    else:
                        print('Ans1-incorrect/unattempted')
            
                    if radioSel2==4:
                        score=score+1 
                        print('Ans2-Correct!')      
                    else:
                        print('Ans2-incorrect/unattempted')
            
                    if radioSel3==2:
                        score=score+1
                        print('Ans3-Correct!')
                    else:
                        print('Ans3-incorrect/unattempted')
                
                    if radioSel4==3:
                        score=score+1
                        print('Ans4-Correct!')
                    else:
                        print('Ans4-incorrect/unattempted')
                
                    if radioSel5==1:
                        score=score+1
                        print('Ans5-Correct!')
                    else:
                        print('Ans5-incorrect/unattempted')
            
                    if radioSel6==2:
                        score=score+1
                        print('Ans6-Correct!')
                    else:
                        print('Ans6-incorrect/unattempted')
            
                    if radioSel7==3:
                        score=score+1
                        print('Ans7-Correct!')
                    else:
                        print('Ans7-incorrect/unattempted')
            
                    if radioSel8==1:
                        score=score+1
                        print('Ans8-Correct!')
                    else:
                        print('Ans8-incorrect/unattempted')
            
                    if radioSel9==4:
                        score=score+1
                        print('Ans9-Correct!')
                    else:
                        print('Ans9-incorrect/unattempted')
            
                    if radioSel10==3:
                        score=score+1
                        print('Ans10-Correct!')
                    else:
                        print('Ans10-incorrect/unattempted')
            
                    if radioSel11==2:
                        score=score+1
                        print('Ans11-Correct!')
                    else:
                        print('Ans11-incorrect/unattempted')
                
                    if radioSel12==2:
                        score=score+1
                        print('Ans12-Correct!')
                    else:
                        print('Ans12-incorrect/unattempted')
                
                    if radioSel13==3:
                        score=score+1 
                        print('Ans13-Correct!')
                    else:
                        print('Ans13-incorrect/unattempted')
                
                    if radioSel14==3:
                        score=score+1
                        print('Ans14-Correct!')
                    else:
                        print('Ans14-incorrect/unattempted')
                
                    if radioSel15==4:
                        score=score+1 
                        print('Ans15-Correct!')
                    else:
                        print('Ans15-incorrect/unattempted')
                
                    if radioSel16==4:
                        score=score+1
                        print('Ans16-Correct!')
                    else:
                        print('Ans16-incorrect/unattempted')
                        
                    if radioSel17==1:
                        score=score+1
                        print('Ans17-Correct!')
                    else:
                        print('Ans17-incorrect/unattempted')
                
                    if radioSel18==2:
                        score=score+1
                        print('Ans18-Correct!')
                    else:
                        print('Ans18-incorrect/unattempted')
                        
                    if radioSel19==3:
                        score=score+1
                        print('Ans19-Correct!')
                    else:
                        print('Ans19-incorrect/unattempted')
                
                    if radioSel20==1:
                        score=score+1
                        print('Ans20-Correct!')
                    else:
                        print('Ans20-incorrect/unattempted')
                        
                    if radioSel21==4:
                        score=score+1
                        print('Ans21-Correct!')
                    else:
                        print('Ans21-incorrect/unattempted')
                
                    if radioSel22==2:
                        score=score+1
                        print('Ans22-Correct!')
                    else:
                        print('Ans22-incorrect/unattempted')
                        
                    if radioSel23==3:
                        score=score+1
                        print('Ans23-Correct!')
                    else:
                        print('Ans23-incorrect/unattempted')
                
                    if radioSel24==2:
                        score=score+1
                        print('Ans24-Correct!')
                    else:
                        print('Ans24-incorrect/unattempted')
                        
                    if radioSel25==4:
                        score=score+1
                        print('Ans25-Correct!')
                    else:
                        print('Ans25-incorrect/unattempted')
                print("Your total score is",score)
                f7= Frame(root3,height=1000,width=2000,bg='sky blue')
                t6=Label(f7,text='Your total score is : '+str(score),font=('bold',45),bg='sky blue')
                t6.place(x=400,y=170)
                t7=Label(f7,text='THANK YOU',font=('bold',40),bg='sky blue')
                t7.place(x=510,y=370)
                f7.pack()
    
            f6= Frame(root3,height=1000,width=2000,bg='sky blue')
            t5=Label(f6,text='Q21. India Share its maximum Border Area with which country?',font=('bold',20),bg='sky blue')
            t5.place(x=10,y=30)
            r93 = Radiobutton(f6, text="China", variable=var24, value=1,font=('bold',14),bg='sky blue',fg='brown')
            r93.place(x=10,y=80)
            r94 = Radiobutton(f6, text="Bangladesh", variable=var24, value=2,font=('bold',14),bg='sky blue',fg='brown')
            r94.place(x=190,y=80)
            r95 = Radiobutton(f6, text="Pakistan", variable=var24, value=3,font=('bold',14),bg='sky blue',fg='brown')
            r95.place(x=10,y=120)
            r96= Radiobutton(f6, text="Nepal", variable=var24, value=4,font=('bold',14),bg='sky blue',fg='brown')
            r96.place(x=190,y=120)
    
            t5=Label(f6,text='Q22. Which is greatest among the following fractions? ',font=('bold',20),bg='sky blue')
            t5.place(x=10,y=170)
            r97 = Radiobutton(f6, text="1/2", variable=var25, value=1,font=('bold',14),bg='sky blue',fg='brown')
            r97.place(x=10,y=220)
            r98 = Radiobutton(f6, text="9/11", variable=var25, value=2,font=('bold',14),bg='sky blue',fg='brown')
            r98.place(x=190,y=220)
            r99 = Radiobutton(f6, text="4/6", variable=var25, value=3,font=('bold',14),bg='sky blue',fg='brown')
            r99.place(x=10,y=260)
            r100= Radiobutton(f6, text="7/2", variable=var25, value=4,font=('bold',14),bg='sky blue',fg='brown')
            r100.place(x=190,y=260)
            
            t2=Label(f6,text='Q23. Which State is called the sugar bowl of india? ',font=('bold',20),bg='sky blue')
            t2.place(x=10,y=310)
            r41 = Radiobutton(f6, text="Maharashtra", variable=var11, value=1,font=('bold',14),bg='sky blue',fg='brown')
            r41.place(x=10,y=360)
            r42 = Radiobutton(f6, text="Uttar Pradesh", variable=var11, value=2,font=('bold',14),bg='sky blue',fg='brown')
            r42.place(x=190,y=360)
            r43 = Radiobutton(f6, text="Tamil Nadu", variable=var11, value=3,font=('bold',14),bg='sky blue',fg='brown')
            r43.place(x=10,y=390)
            r44= Radiobutton(f6, text="Odisha", variable=var11, value=4,font=('bold',14),bg='sky blue',fg='brown')
            r44.place(x=190,y=390)
            
            t3=Label(f6,text='Q24. Who is the chief justice of India? ',font=('bold',20),bg='sky blue')
            t3.place(x=10,y=440)
            r65 = Radiobutton(f6, text="Dipak Misra", variable=var17, value=1,font=('bold',14),bg='sky blue',fg='brown')
            r65.place(x=10,y=490)
            r66 = Radiobutton(f6, text="Jagdish Singh Khehar", variable=var17, value=2,font=('bold',14),bg='sky blue',fg='brown')
            r66.place(x=190,y=490)
            r67 = Radiobutton(f6, text="T.S. Thakur", variable=var17, value=3,font=('bold',14),bg='sky blue',fg='brown')
            r67.place(x=10,y=520)
            r68= Radiobutton(f6, text="H.L. Dattu", variable=var17, value=4,font=('bold',14),bg='sky blue',fg='brown')
            r68.place(x=190,y=520)
            
            t4=Label(f6,text="Q25. Which is the most spoken language in the world? ",font=('bold',20),bg='sky blue')
            t4.place(x=10,y=570)
            r89 = Radiobutton(f6, text="Spanish", variable=var23, value=1,font=('bold',14),bg='sky blue',fg='brown')
            r89.place(x=10,y=620)
            r90 = Radiobutton(f6, text="English", variable=var23, value=2,font=('bold',14),bg='sky blue',fg='brown')
            r90.place(x=190,y=620)
            r91 = Radiobutton(f6, text="Mandarin Chinese", variable=var23, value=3,font=('bold',14),bg='sky blue',fg='brown')
            r91.place(x=10,y=650)
            r92= Radiobutton(f6, text="Russian", variable=var23, value=4,font=('bold',14),bg='sky blue',fg='brown')
            r92.place(x=190,y=650)
            B4=Button(f6,height=2,width=20,text='Submit',command=sel5,font=('bold',15),bg='brown',fg='white')
            B4.place(x=1000,y=650)
            
            B0=Button(f1,height=2,width=20,text='Start',command=sel,font=('bold',15),bg='brown',fg='white')
            B0.place(x=450,y=580)
            f1.pack()
            root3.mainloop() 
           
        Welcome()    

    else:
        r = Tk()
        r.title('OOPS!')
        r.geometry('5000x4000')
        FB=Frame(r,height=5000,width=4000)
        rlbl = Label(FB, text='\n[!] Invalid Login',width=35,font=("bold",50),fg="brown")
        rlbl.pack()
        FB.pack()
        r.mainloop()
def DelUser():
    os.remove(creds)
    rootA.destroy()
    Signup()
if os.path.isfile(creds):
    Login()
else:
    Signup()
# Out:
# Ans1-incorrect/unattempted
# Ans2-Correct!
# Ans3-Correct!
# Ans4-Correct!
# Ans5-Correct!
# Ans6-Correct!
# Ans7-Correct!
# Ans8-Correct!
# Ans9-Correct!
# Ans10-Correct!
# Ans11-Correct!
# Ans12-Correct!
# Ans13-Correct!
# Ans14-Correct!
# Ans15-Correct!
# Ans16-incorrect/unattempted
# Ans17-Correct!
# Ans18-Correct!
# Ans19-Correct!
# Ans20-Correct!
# Ans21-Correct!
# Ans22-Correct!
# Ans23-incorrect/unattempted
# Ans24-incorrect/unattempted
# Ans25-Correct!
# Your total score is 21

# %%
from tkinter import *


app = Tk()


label = Label(app, text="", width=10)
label.pack()
app.mainloop()
remaining = 0
countdown(3600)


    
    
    
    
def countdown(remaining = None):
    if remaining is not None:
        remaining = remaining

    if remaining <= 0:
        label.configure(text="time's up!")
    else:
        label.configure(text='{}'.format(remaining))
        remaining = remaining - 1
        after(1000, countdown)
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# <ipython-input-69-2e7a6bf231ea> in <module>()
#       9 app.mainloop()
#      10 remaining = 0
# ---> 11 countdown(3600)
#      12
#      13
#
# <ipython-input-40-42aec4ded8a1> in countdown(remaining)
#      14         label.configure(text="time's up!")
#      15     else:
# ---> 16         label.configure(text="%d" % remaining)
#      17         remaining = remaining - 1
#      18         after(1000, countdown)
#
# ~\Anaconda3\lib\tkinter\__init__.py in configure(self, cnf, **kw)
#    1480         the allowed keyword arguments call the method keys.
#    1481         """
# -> 1482         return self._configure('configure', cnf, kw)
#    1483     config = configure
#    1484     def cget(self, key):
#
# ~\Anaconda3\lib\tkinter\__init__.py in _configure(self, cmd, cnf, kw)
#    1471         if isinstance(cnf, str):
# ...
